# %%
import betfairlightweight
from bet.config import settings
import json
import datetime

# %%
trading = betfairlightweight.APIClient(
    settings.username,
    settings.password,
    app_key=settings.app_key,
    certs=settings.certs_dir,
)

# %%
trading.login()

# %%
event_ids = [33676118]

# %%
scores = trading.in_play_service.get_scores(event_ids=event_ids)

# %%
for score in scores:
    print(
        score,
        score.description,
        score.status,
        "%s-%s" % (score.score.home.score, score.score.away.score),
    )  # view resources or debug to see all values available
# Out:
# Scores None SecondHalfKickOff 1-0

# %%
scores[0].score.home.score
# Out:
# '1'

# %%
event_timeline = trading.in_play_service.get_event_timeline(event_id=33676118)

# %%
dir(event_timeline)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_datetime_created',
#  '_datetime_updated',
#  'elapsed_regular_time',
#  'elapsed_time',
#  'event_id',
#  'event_type_id',
#  'in_play_match_status',
#  'json',
#  'score',
#  'status',
#  'strip_datetime',
#  'time_elapsed',
#  'update_detail']

# %%
et = json.loads(event_timeline.json())

# %%
et.keys()
# Out:
# dict_keys(['eventId', 'eventTypeId', 'score', 'timeElapsed', 'elapsedRegularTime', 'elapsedAddedTime', 'updateDetails', 'status', 'inPlayMatchStatus'])

# %%
print(et)
# Out:
# {'eventId': 33676118, 'eventTypeId': 1, 'score': {'home': {'name': 'Universidad de Venezuela', 'score': '1', 'halfTimeScore': '1', 'fullTimeScore': '', 'penaltiesScore': '', 'penaltiesSequence': [], 'games': '', 'sets': '', 'numberOfYellowCards': 2, 'numberOfRedCards': 0, 'numberOfCards': 2, 'numberOfCorners': 3, 'numberOfCornersFirstHalf': 3, 'bookingPoints': 20}, 'away': {'name': 'Caracas', 'score': '0', 'halfTimeScore': '0', 'fullTimeScore': '', 'penaltiesScore': '', 'penaltiesSequence': [], 'games': '', 'sets': '', 'numberOfYellowCards': 0, 'numberOfRedCards': 0, 'numberOfCards': 0, 'numberOfCorners': 4, 'numberOfCornersFirstHalf': 4, 'bookingPoints': 0}, 'numberOfYellowCards': 2, 'numberOfRedCards': 0, 'numberOfCards': 2, 'numberOfCorners': 7, 'numberOfCornersFirstHalf': 7, 'bookingPoints': 20}, 'timeElapsed': 48, 'elapsedRegularTime': 45, 'elapsedAddedTime': 3, 'updateDetails': [{'updateTime': '2024-10-13T23:30:07.225Z', 'updateId': 9, 'matchTime': 1, 'elapsedRegularTime': 1, '
# ...

# %%
et['inPlayMatchStatus']
# Out:
# [{'updateTime': '2024-10-13T23:30:07.225Z', 'updateId': 9, 'matchTime': 1, 'elapsedRegularTime': 1, 'type': 'KickOff', 'updateType': 'KickOff'}, {'updateTime': '2024-10-13T23:41:17.327Z', 'updateId': 23, 'team': 'home', 'teamName': 'Universidad de Venezuela', 'matchTime': 12, 'elapsedRegularTime': 12, 'type': 'Goal', 'updateType': 'Goal'}, {'updateTime': '2024-10-13T23:57:59.586Z', 'updateId': 41, 'team': 'home', 'teamName': 'Universidad de Venezuela', 'matchTime': 28, 'elapsedRegularTime': 28, 'type': 'YellowCard', 'updateType': 'YellowCard'}, {'updateTime': '2024-10-14T00:09:21.415Z', 'updateId': 55, 'team': 'home', 'teamName': 'Universidad de Venezuela', 'matchTime': 40, 'elapsedRegularTime': 40, 'type': 'YellowCard', 'updateType': 'YellowCard'}, {'updateTime': '2024-10-14T00:18:11.333Z', 'updateId': 74, 'matchTime': 49, 'elapsedRegularTime': 45, 'elapsedAddedTime': 4, 'type': 'FirstHalfEnd', 'updateType': 'FirstHalfEnd'}]

# %%
from betfairlightweight.filters import market_filter

# %%
scores[0].score.home.score
# Out:
# '3'

# %%
# score request (provide list / returns list)
scores = trading.in_play_service.get_scores(event_ids=event_ids)

# %%
scores[0].json()
# Out:
# '{"eventTypeId": 1, "eventId": 33676087, "score": {"home": {"name": "Cucuta Deportivo", "score": "3", "halfTimeScore": "3", "fullTimeScore": "", "penaltiesScore": "", "penaltiesSequence": [], "games": "", "sets": "", "highlight": false, "numberOfYellowCards": 3, "numberOfRedCards": 0, "numberOfCards": 3, "numberOfCorners": 1, "numberOfCornersFirstHalf": 0, "numberOfCornersSecondHalf": 1, "bookingPoints": 30}, "away": {"name": "Quindio", "score": "1", "halfTimeScore": "1", "fullTimeScore": "", "penaltiesScore": "", "penaltiesSequence": [], "games": "", "sets": "", "highlight": true, "numberOfYellowCards": 3, "numberOfRedCards": 1, "numberOfCards": 4, "numberOfCorners": 1, "numberOfCornersFirstHalf": 1, "numberOfCornersSecondHalf": 0, "bookingPoints": 55}, "numberOfYellowCards": 6, "numberOfRedCards": 1, "numberOfCards": 7, "numberOfCorners": 2, "numberOfCornersFirstHalf": 1, "numberOfCornersSecondHalf": 1, "bookingPoints": 85}, "timeElapsed": 90, "elapsedRegularTime": 90, "hasSets": f
# ...

# %%
for event_id in event_ids:
    event_time_line = trading.in_play_service.get_event_timeline(event_id=event_id)
    for update_detail in event_time_line.update_detail:
        if (update_detail.type == "Goal" 
            and  update_detail.match_time > 45 
            and update_detail.elapsed_regular_time > 45
           ):
            print(update_detail.type, update_detail.match_time, update_detail.team_name)
# Out:
# Goal 51 Orsomarso

# %%
for update_detail in event_time_line.update_detail:
    if update_detail.type == "Goal":
        print(update_detail.type, update_detail.match_time, update_detail.team_name)
# Out:
# Goal 35 Once Caldas

# %%
dir(event_time_line.update_detail[0])
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'elapsed_added_time', 'elapsed_regular_time', 'match_time', 'player', 'team', 'team_name', 'type', 'update_id', 'update_time', 'update_type']

# %%
event_time_line.json()
# Out:
# '{"eventId": 33667777, "eventTypeId": 1, "score": {"home": {"name": "Sporting Gijon", "score": "1", "halfTimeScore": "0", "fullTimeScore": "", "penaltiesScore": "", "penaltiesSequence": [], "games": "", "sets": "", "numberOfYellowCards": 1, "numberOfRedCards": 0, "numberOfCards": 1, "numberOfCorners": 5, "numberOfCornersFirstHalf": 2, "numberOfCornersSecondHalf": 3, "bookingPoints": 10}, "away": {"name": "CD Castellon", "score": "1", "halfTimeScore": "1", "fullTimeScore": "", "penaltiesScore": "", "penaltiesSequence": [], "games": "", "sets": "", "numberOfYellowCards": 2, "numberOfRedCards": 0, "numberOfCards": 2, "numberOfCorners": 2, "numberOfCornersFirstHalf": 1, "numberOfCornersSecondHalf": 1, "bookingPoints": 20}, "numberOfYellowCards": 3, "numberOfRedCards": 0, "numberOfCards": 3, "numberOfCorners": 7, "numberOfCornersFirstHalf": 3, "numberOfCornersSecondHalf": 4, "bookingPoints": 30}, "timeElapsed": 73, "elapsedRegularTime": 73, "updateDetails": [{"updateTime": "2024-10-14T18:
# ...

# %%
event_ids
# Out:
# ['33683392', '33674499', '33674804', '33676118', '33683562', '33664094']

# %%
timeline = trading.in_play_service.get_event_timeline(event_id=event_ids[0])
#print(timeline)
for update in timeline.update_detail:
    print(
        update
        #update.update_id, update.elapsed_regular_time, update.type, update.update_time
    )  # view resources or debug to see all values available

# %%
dir(timeline.update_detail[0])
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'elapsed_added_time', 'elapsed_regular_time', 'match_time', 'player', 'team', 'team_name', 'type', 'update_id', 'update_time', 'update_type']

# %%
for event in events:
    event_start = event.event.open_date
    current_time = datetime.datetime.utcnow()
    time_elapsed = current_time - event_start
    
    # Exibir o tempo de jogo em minutos
    minutes_elapsed = divmod(time_elapsed.total_seconds(), 60)[0]
    print(f"Tempo de jogo: {int(minutes_elapsed)} minutos")
# Out:
# Tempo de jogo: 66 minutos
# Tempo de jogo: 36 minutos
# Tempo de jogo: 30 minutos
# Tempo de jogo: 116 minutos

# %%
for event in events:
    print(f"Evento: {event.event.name}")
    print(f"Data de início: {event.event.open_date}")
    print(f"ID do Evento: {event.event.id}")
# Out:
# Evento: Sporting Gijon v CD Castellon
# Data de início: 2024-10-14 18:30:00
# ID do Evento: 33667777
# Evento: Italy v Israel
# Data de início: 2024-10-14 18:45:00
# ID do Evento: 33679267
# Evento: England U20 v Czech Republic U20
# Data de início: 2024-10-14 18:00:00
# ID do Evento: 33686336
# Evento: Bosnia v Hungary
# Data de início: 2024-10-14 18:45:00
# ID do Evento: 33679269
# Evento: St Ives Town v Biggleswade Town
# Data de início: 2024-10-14 18:45:00
# ID do Evento: 33688390
# Evento: Iceland v Turkey
# Data de início: 2024-10-14 18:45:00
# ID do Evento: 33680484
# Evento: AD Berazategui v Victoriano Arenas
# Data de início: 2024-10-14 18:00:00
# ID do Evento: 33686634
# Evento: Almirante Brown v Atletico Rafaela
# Data de início: 2024-10-14 18:30:00
# ID do Evento: 33669320
# Evento: Estonia v Sweden
# Data de início: 2024-10-14 18:45:00
# ID do Evento: 33682506
# Evento: Atletico Goianiense U20 v Guanabara City U20
# Data de início: 2024-10-14 18:30:00
# ...

# %%
timeline = trading.in_play_service.get_event_timeline(event_id=33698897)
#print(timeline)

for update in timeline.update_detail:
    print(
        update.match_time,
        update.update_type
        #update.update_id, update.elapsed_regular_time, update.type, update.update_time
    )  # view resources or debug to see all values available
# Out:
# 1 KickOff
# 12 Goal
# 32 YellowCard
# 34 YellowCard
# 45 YellowCard
# 48 FirstHalfEnd
# 46 SecondHalfKickOff
# 47 YellowCard
# 56 YellowCard

# %%
ev = trading.betting.list_events(filter=event_filter)

# %%
ev[0].event.id
# Out:
# '33699078'

# %%
ev[0].event.competition.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 ev[0].event.competition.name
#
# AttributeError: 'Event' object has no attribute 'competition'

# %%
set([e.event.country_code for e in ev])
# Out:
# {'AT', 'DE', 'NL', 'CH', 'GB', 'RO', 'MA', 'IT', 'EC', 'ES', 'IE', 'BE', 'SA', 'AR', 'GI', 'PT', 'DZ', 'BO', 'PL', 'FR'}

# %%
dir(trading.in_play_service.get_event_timeline(event_id=33699078))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_data', '_datetime_created', '_datetime_updated', 'elapsed_regular_time', 'elapsed_time', 'event_id', 'event_type_id', 'in_play_match_status', 'json', 'score', 'status', 'strip_datetime', 'time_elapsed', 'update_detail']

# %%
scores = trading.in_play_service.get_scores(event_ids=[33699078])

# %%
dir(score)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_data', '_datetime_created', '_datetime_updated', 'current_day', 'current_game', 'current_point', 'current_set', 'description', 'elapsed_added_time', 'elapsed_regular_time', 'elapsed_time', 'event_id', 'event_type_id', 'full_time_elapsed', 'json', 'match_status', 'match_type', 'score', 'state_of_ball', 'status', 'strip_datetime', 'time_elapsed', 'time_elapsed_seconds']

# %%
event_filter = {
    'filter': {
        'eventTypeIds': ['1'],  # 1 representa eventos de Futebol
        'inPlayOnly': True  # Apenas eventos que estão ao vivo
    }
}

# Liste os eventos de futebol ao vivo
events = trading.betting.list_events(event_filter)

# %%
for event in events:
    event_name = event.event.name
    competition_name = event.event.competition.name if event.event.competition else 'Desconhecido'
    country = event.event.venue if event.event.venue else 'Desconhecido'

    print(f"Evento: {event_name}, Competição: {competition_name}, País: {country}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[240], line 3
#       1 for event in events:
#       2     event_name = event.event.name
# ----> 3     competition_name = event.event.competition.name if event.event.competition else 'Desconhecido'
#       4     country = event.event.venue if event.event.venue else 'Desconhecido'
#       6     print(f"Evento: {event_name}, Competição: {competition_name}, País: {country}")
#
# AttributeError: 'Event' object has no attribute 'competition'

# %%
# Defina os filtros para eventos ao vivo de futebol
event_filter = {
    'filter': {
        'eventIds': [33699009],  # 1 representa eventos de Futebol
        #'inPlayOnly': True  # Apenas eventos que estão ao vivo
    }
}

# Liste os eventos de futebol ao vivo
event2 = trading.betting.list_events(event_filter)
